# %%
limite = 4
import random

# Contador de ejecuciones
ejecuciones = 0

def sorteo():
    global ejecuciones
    ejecuciones += 1

    if ejecuciones != limite:
        ganador = random.choice(nombres)
        print(f"Eliminado {ganador}")
    else:
        print("El ganador es bbromelly La @botanicuom.studio")

nombres = [
    "paoolasaenz @develop_arquitectos",
    "sedientadepalabras @sedientadepalabras",
    "nancy.nevarez @elpeludosnaks",
    "nat.valdivia @uxspaces.oficial",
    "sakurablossom65 @happy_julybri",
    "lavieenrose.1991 @lavieenrose.1991 🙌🙌🙌🙌 fotografía",
    "nicelove0592 @gomita5439 😍or",
    "daranggil @fezlys",
    "itzi.ari Ya quedó 💜 @tia_elsita 🐽🏃🏻‍♀️",
    "lavanddah @botanicuom.studio 💜",
    "mg2022072 @mg2022072",
    "prim_averaosorio @jobesus",
    "alex_schloss @vainavegana",
    "botanicuom.studio ✨ @botanicuom.studio ✨",
    "monicaameliavolante @mala_blada",
    "jburgosper @boxitashouse",
    "nancy_manee @pinatasmane",
    "garzaachristian555 @555tclb",
    "olivaarr_ @olivar1998_",
    "botanicuom.studio @botanicuom.studio ✨",
    "esthela6098 @me.gr88",
    "karenlilianaderivera @caro.roque.gomez",
    "itzi.ari @academiatei",
    "viri_hercar @uranem para tu emprendimiento artesanal, deberías concursar",
    "nat.valdivia @euloggia.mx",
    "daranggil @mitzi.makeup.artist",
    "pauromero @punto.magicoqro",
    "bbromelly Mi emprendedora fav está empezando @botanicuom.studio",
    "nicelove0592 @ojito_scolorcafe",
    "itzi.ari @bam.boo16",
    "doni_l0p @gosygonza",
    "cd.berenice @fostercolor 😍",
    "brillito.azul.82 @davila.b.12",
    "memes_tio_times @gigapixel_cuernavaca",
    "breencorrea @adri_cr.91",
    "ap_orozco @curada.studio @ap_orozco",
    "sakurablossom65 @lluviaglam 🌬️🌌🐾",
    "itzi.ari @laspinatascoatza",
    "merakiduo_cosplay @merakiduo_cosplay",
    "regina_fregoso @fikaafitbar",
    "daranggil @aleluballons",
    "lesfriv @mama_y_enfermera_a_la_vez",
    "alexia.gloom @bagancia.mx",
    "pet.jack_ @pet.jack_",
    "caramelo_barrios @dufferscookies",
    "montsemaximo @bocadilloshuerta",
    "pauromero @euloggia.mx",
    "cleptosaury @botanicuom.studio ;)",
    "ilse.daffitness @kraftesanias 🙋🏻‍♀️",
    "ironsquadmexico @ironsquadmexico",
    "sara.bnvds @lilibenavidesc",
    "edgar.tugger @shirbupe",
    "nalaysimba1712 @pimienta.mexico",
    "bbromelly La @botanicuom.studio",
    "alex_schloss @thebodymist.mx",
    "ulisesdaniellopez @rajisimasconsabor",
    "marahzp @kreativaseventosydetalles",
    "socorro_mdn @lapalapadeltiofito",
    "bety_adri_ Cuándo anuncian al ganador 🏆???",
    "itzi.ari @peksbazar",
    "ap_orozco @aporozco @___tiempoaltiempo",
    "anaclaudiau @pao_alarcon11",
    "gabpok81 @mentalavandaqro",
    "bety_adri_ @migueltierrablanca7777",
    "itzi.ari @gumapape",
    "anaclaudiau @danielsoto.p",
    "brillito.azul.82 @mar.prado.34",
    "daranggil #PurpleIdeasmt x #xavierespinosa",
    "anaclaudiau @sarubbina",
    "licha_mar60 @boxitashouse",
    "bbromelly De mi amix @botanicuom.studio",
    "pao_hdez @cherry_paperstore",
    "victor.vg94 @woncheese_mty",
    "victoria.vch @mooz_mx",
    "paoolasaenz @grekka.furniture",
    "daranggil @loka_pop_store",
    "mariah____mar @merryrvr",
    "daranggil @mary_boutiqueonlinenn",
    "anaclaudiau @broder.basics",
    "caramelo_barrios @pim_candles",
    "jannia554.cr @yomiy53",
    "caramelo_barrios @paopalmerin",
    "yolymeugniot @creaciones_jady",
    "betty.p.silva @the_detailers_puebla",
    "bonito_taller.mx @bonito_taller.mx",
    "mrsbenavidesv @sara.bnvds",
    "karenlilianaderivera @deividzoto",
    "dc_mx24 @villanovamx",
    "danielita.gupa @ana.ariaz5",
    "marco_car87 @shirbupe",
    "alexia.gloom @pretty_nails_dany",
    "merryrvr @merryrvr",
    "an.mar.flor32 @jannia554.cr",
    "viri_hercar @auriculoterapia_y_nutricion el emprendimiento es mío @viri_hercar",
    "karenlilianaderivera @espindola.itzel",
    "hechocon_amour @hechocon_amour",
    "diegomoritaa @diegomoritaa",
    "garzaachristian555 @faveera__ @fa_olveera",
    "mi_mundo.color_rosa @rocio.roci5496",
    "diegomoritaa @misterfishmx",
    "sakurablossom65 @crab_of_namjoonie_store",
    "higiniobc @sara.bnvds",
    "alex_schloss @mycoffeecup.karaoke",
    "marco_car87 @boxitashouse",
    "daranggil @rigel18_mx",
    "pablo_vp @ruta_64",
    "nalaysimba1712 @uxspaces.oficial",
    "snacks_ohana15 @snacks_ohana15",
    "ferb_18 @pixel_shop_18",
    "caramelo_barrios @davvidochoa",
    "karenlilianaderivera @soto.cristal",
    "socorro_mdn @gisellecarrillo_nailstudio",
    "marifer_glezm @margon_dgf",
    "domguezmaria @merryrvr",
    "42326._ @chikachile_",
    "anaclaudiau @the.hopestore",
    "licha_mar60 @shirbupe",
    "paoolasaenz @mariscoslavia",
    "lilibenavidesc @sara.bnvds",
    "anaclaudiau @nenagalvez",
    "paoolasaenz @sukhaa_studio",
    "plantasiah_ @botanicuom.studio",
    "breencorrea @davila.b.12",
    "botanicuom.studio @botanicuom.studio ✨🤍🈯",
    "jannia554.cr @magic.love5",
    "roxvigueras @sara.bnvds",
    "mirandda.mr @merryrvr",
    "pablo_vp @nubecita.bag",
    "edgar.tugger @boxitashouse",
    "vera_arredondo @erikamoreno6486",
    "fostercolor @nenalin.cr",
    "mabasinaloa @mb.elquelite tengo mi página en Facebook artesanias y manualidades MB el quelite",
    "botanicuom.studio @botanicuom.studio c:",
    "cd.berenice @an.mar.flor32 💕necesitas",
    "alex_schloss @tu_pijama.mx",
    "adri_cr.91 @an.mar.flor32",
    "sara.bnvds @sara.bnvds",
    "jburgosper @shirbupe",
    "criaturaural @botanicuom.studio",
    "caramelo_barrios @ruta_64",
    "danielita.gupa @mariianasalmeronn",
    "joelgonz98 @dalia.club",
    "belen.carlo @aguadulcemid",
    "davila.b.12 @princez_da_1632",
    "rosario.gutierrez25 @faticasillas.farmasi 😍😍😍",
    "rocio.roci5496 @breencorrea c🍀🤞🏻",
    "maryy____anna @medinna_arturo",
    "brianna_69_ @marycel_rmm",
    "marinnamarii @medinna_arturo",
    "marye____toh69 @merryrvr",
    "mara.sweet69 @merryrvr",
    "mara.sweet69 @medinna_arturo",
    "gomita5439 @davila.b.12",
    "maryy___anna @la_mariis",
    "brianna_69_ @merryrvr",
    "marinnamarii @merryrvr",
    "ita___mrs @marycel_rmm",
    "ma.rvm33 @medinna_arturo 💈🧔🏻",
    "marinnamarii @marycel_rmm",
    "la__mariis @medinna_arturo",
    "jos.egarcia20 @merryrvr",
    "marye____toh69 @medinna_arturo",
    "___marinna @marycel_rmm",
    "mariia___i_s_a @marycel_rmm",
    "aliss.caren23 @brillito.azul.82",
    "maryy____anna @mariiie_35647",
    "jos.egarcia20 @marycel_rmm",
    "plantasiah_ @botanicuom.studio 🌼",
    "maryy____anna @medinna_arturo",
    "jos.egarcia20 @marixita.rime",
    "ma.rvm33 @marycel_rmm 🍗🍗",
    "princez_da_1632 @brillito.azul.82",
    "ita___mrs @merryrvr",
    "ita___mrs @medinna_arturo",
    "botanicuom.studio @botanicuom.studio 🈯",
    "lizbethmeri.meri @merryrvr",
    "princez_da_1632 @fostercolor ❤️",
    "marixita.rime @marycel_rmm",
    "ma.rvm33 @merryrvr",
    "lizbethmeri.meri @medinna_arturo",
    "___marinna @merryrvr",
    "marixita.rime @merryrvr",
    "ojito_scolorcafe @an.mar.flor32",
    "plantasiah_ @botanicuom.studio ✿✿⁠",
    "kenia.mariia_ @marycel_rmm 👏🏻",
    "___marinna @merryrvr",
    "sari.sari109 @rocio.roci5496",
    "lidia8815 @nenalin.cr",
    "yomiy53 @rocio.roci5496",
    "nenalin.cr @mar.prado.34",
    "mariiie_35647 @marycel_rmm",
    "mariia___i_s_a @merryrvr",
    "marinnamarii @merryrvr",
    "marimdo86 @merryrvr",
    "marinnamarii @medinna_arturo",
    "maryy____anna @marycel_rmm",
    "kenia.mariia_ @medinna_arturo 👏",
    "mariiie_35647 @medinna_arturo",
    "magic.love5 @lidia8815",
    "mariia___i_s_a @medinna_arturo",
    "maryy____anna @merryrvr",
    "marinnamarii @marycel_rmm",
    "plantasiah_ @botanicuom.studio 🍀",
    "merryrvr @medinna_arturo",
    "botanicuom.studio @botanicuom.studio ㊗️",
    "botanicuom.studio @botanicuom.studio 🤍",
    "mariia___i_s_a @merryrvr",
    "maryy____anna @marycel_rmm",
    "marye____toh69 @marycel_rmm",
    "marimdo86 @marycel_rmm",
    "plantasiah_ @botanicuom.studio ✿⁠",
    "calica365 🌸🎉 @itzi.ari",
    "la__mariis @merryrvr",
    "mariah____mar @medinna_arturo",
    "maryy____anna @marinnamarii",
    "marixita.rime @mary_oct18",
    "calica365 @daranggil",
    "aliss.caren23 @princez_da_1632",
    "marye____toh69 @marycel_rmm",
    "marixita.rime @marye____toh69",
    "ita___mrs @marycel_rmm",
    "la__mariis @marycel_rmm",
    "calica365 Listo con mis amigas emprendedoras!!",
    "mariiie_35647 @merryrvr",
    "jos.egarcia20 @marycel_rmm",
    "merryrvr @marycel_rmm",
    "jos.egarcia20 @medinna_arturo",
    "ojito_scolorcafe @rocio.roci5496 🤫🍀🫶🏻",
    "estrellita_1205 @rocio.roci5496",
    "mariah____mar @marycel_rmm",
    "maryy____anna @marixita.rime",
    "___marinna @medinna_arturo",
    "___marinna @medinna_arturo",
    "plantasiah_ @botanicuom.studio 🍊",
    "mar.prado.34 @nenalin.cr",
    "marixita.rime @medinna_arturo",
    "jos.egarcia20 @mariah____mar",
    "marimdo86 @medinna_arturo",
    "marye____toh69 @marimdo86",
    "brianna_69_ @medinna_arturo tú",
    "jos.egarcia20 @merryrvr",
    "mariiie_35647 @medinna_arturo",
    "mara.sweet69 @marycel_rmm",
    "calica365 @sakurablossom65",
    "bere_bere.d @brillito.azul.82",
    "kenia.mariia_ @merryrvr 👏",
    "mariia___i_s_a @medinna_arturo",
    "ita___mrs @merryrvr",
    "princez_da_1632 @bere_bere.d"
]

# %%
sorteo()
# Out:
# El ganador es bbromelly La @botanicuom.studio
